# %% [markdown]
# #Realizar un embedding para el campo text y visualizarlo con alguna técnica de reducción de visualizaciones distinta a PCA. En base a la visualización,
#
# ##¿Sería posible predecir el target con este embedding? (2 punto)

# %%
# @title 1. Instalación de Librerías e Importaciones

# !pip install -U gensim

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

import nltk
from nltk.tokenize import TweetTokenizer
from gensim.models import Word2Vec
from sklearn.manifold import TSNE
nltk.download('punkt')
# Out:
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.0.1)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 50.8 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# @title Semilla y Carga de Datos

SEMILLA = 111014

# Cargar datos
train_file = '/content/drive/MyDrive/MATERIAS/Ciencia de Datos/nlp-getting-started/train.csv'
df_train = pd.read_csv(train_file)

print(f"Datos cargados: {df_train.shape}")
# Out:
# Datos cargados: (7613, 5)

# %%
# @title 3. Preprocesamiento (Tokenización)

tk = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

def preprocesar_tweet(text):
    if pd.isna(text): return []
    tokens = tk.tokenize(text)
    tokens = [token for token in tokens if token.isalnum() or token.startswith('#')]

    return tokens

df_train['tokens'] = df_train['text'].apply(preprocesar_tweet)

# %%
# @title 4. Entrenamiento Word2Vec y Vectorización
w2v_model = Word2Vec(
    sentences=df_train['tokens'],
    vector_size=100,
    window=5,
    min_count=2,
    sg=1,
    seed=SEMILLA,
    workers=4
)

def obtener_vector_promedio(tokens, modelo):
    palabras_validas = [word for word in tokens if word in modelo.wv]

    if len(palabras_validas) > 0:
        return np.mean(modelo.wv[palabras_validas], axis=0)
    else:
        return np.zeros(modelo.vector_size)

embeddings = np.array([obtener_vector_promedio(t, w2v_model) for t in df_train['tokens']])

# %%
# @title 5. Reducción con t-SNE y Visualización

tsne = TSNE(
    n_components=2,
    perplexity=80,
    random_state=SEMILLA,
    learning_rate='auto',
    n_jobs=-1
)

embeddings_2d = tsne.fit_transform(embeddings)

# %%
# 2. Preparar datos para el gráfico
df_viz = df_train.copy()
df_viz['x'] = embeddings_2d[:, 0]
df_viz['y'] = embeddings_2d[:, 1]
df_viz['clase'] = df_viz['target'].map({0: 'No Desastre', 1: 'Desastre'})

# %%
# @title 6. Visualización Interactiva con Plotly
import plotly.express as px
import pandas as pd

df_tsne = pd.DataFrame(embeddings_2d, columns=['x', 'y'])
df_tsne['target_label'] = df_train['target'].map({0: 'No Desastre', 1: 'Desastre'})
df_tsne['text'] = df_train['text']
df_tsne['keyword'] = df_train['keyword'].fillna('Sin Keyword')

fig = px.scatter(
    df_tsne,
    x='x',
    y='y',
    color='target_label',

    hover_data={
        'x': False,
        'y': False,
        'target_label': True,
        'keyword': True,
        'text': True
    },

    title='Embedding de Tweets usando Word2Vec + T-SNE',

    color_discrete_map={'No Desastre': '#808080', 'Desastre': '#C0392B'},

    opacity=0.6,
    width=1000,
    height=800
)

fig.update_traces(marker=dict(size=5))
fig.update_layout(
    legend_title_text='Clase Real',
    template='plotly_white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="00260e30-92f8-441b-ab5b-fa7b57a18476" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("00260e30-92f8-441b-ab5b-fa7b57a18476")) {                    Plotly.newPlot(                        "00260e30-92f8-441b-ab5b-fa7b57a18476",                        [{"customdata":[["Desastre","Sin Keyword","Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all"],["Desastre","Sin Keyword","Forest fire near La Ronge Sask. Canada"],["Desastre","Sin Keyword","All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected"],["Desastre","Sin Keyword","13,000 people receive #wildfires evacuation orders in California "],["Desastre","Sin Keyword","Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school "],["Desastre","Sin Keyword","#RockyFire Update =\u003e California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires"],["Desastre","Sin Keyword","#flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas"],["Desastre","Sin Keyword","I'm on top of the hill and I can see a fire in the woods..."],["Desastre","Sin Keyword","There's an emergency evacuation happening now in the building across the street"],["Desastre","Sin Keyword","I'm afraid that the tornado is coming to our area..."],["Desastre","Sin Keyword","Three people died from the heat wave so far"],["Desastre","Sin Keyword","Haha South Tampa is getting flooded hah- WAIT A SECOND I LIVE IN SOUTH TAMPA WHAT AM I GONNA DO WHAT AM I GONNA DO FVCK #flooding"],["Desastre","Sin Keyword","#raining #flooding #Florida #TampaBay #Tampa 18 or 19 days. I've lost count "],["Desastre","Sin Keyword","#Flood in Bago Myanmar #We arrived Bago"],["Desastre","Sin Keyword","Damage to school bus on 80 in multi car crash #BREAKING "],["Desastre","ablaze","@bbcmtd Wholesale Markets ablaze http:\u002f\u002ft.co\u002flHYXEOHY6C"],["Desastre","ablaze","#AFRICANBAZE: Breaking news:Nigeria flag set ablaze in Aba. http:\u002f\u002ft.co\u002f2nndBGwyEi"],["Desastre","ablaze","INEC Office in Abia Set Ablaze - http:\u002f\u002ft.co\u002f3ImaomknnA"],["Desastre","ablaze","Barbados #Bridgetown JAMAICA ÛÒ Two cars set ablaze: SANTA CRUZ ÛÓ Head of the St Elizabeth Police Superintende...  http:\u002f\u002ft.co\u002fwDUEaj8Q4J"],["Desastre","ablaze","How the West was burned: Thousands of wildfires ablaze in California alone http:\u002f\u002ft.co\u002fvl5TBR3wbr"],["Desastre","ablaze","Deputies: Man shot before Brighton home set ablaze http:\u002f\u002ft.co\u002fgWNRhMSO8k"],["Desastre","ablaze","Man wife get six years jail for setting ablaze niece\nhttp:\u002f\u002ft.co\u002feV1ahOUCZA"],["Desastre","ablaze","Police: Arsonist Deliberately Set Black Church In North CarolinaåÊAblaze http:\u002f\u002ft.co\u002fpcXarbH9An"],["Desastre","ablaze","#Kurds trampling on Turkmen flag later set it ablaze while others vandalized offices of Turkmen Front in #Diyala http:\u002f\u002ft.co\u002f4IzFdYC3cg"],["Desastre","ablaze","TRUCK ABLAZE : R21. VOORTREKKER AVE. OUTSIDE OR TAMBO INTL. CARGO SECTION. http:\u002f\u002ft.co\u002f8kscqKfKkF"],["Desastre","ablaze","How the West was burned: Thousands of wildfires ablaze in #California alone http:\u002f\u002ft.co\u002fiCSjGZ9tE1 #climate #energy http:\u002f\u002ft.co\u002f9FxmN0l0Bd"],["Desastre","ablaze","@Navista7 Steve these fires out here are something else! California is a tinderbox - and this clown was setting my 'hood ablaze @News24680"],["Desastre","ablaze","@nxwestmidlands huge fire at Wholesale markets ablaze http:\u002f\u002ft.co\u002frwzbFVNXER"],["Desastre","accident","Accident on I-24 W #NashvilleTra ...

# %% [markdown]
# # ¿Sería posible predecir el target con este embedding?
#
# ### Con este embedding seria un poco dificil definir el target, pero podemos ver que hay zonas en las que predomina un target más que otro.
#
# Podemos ver que la zona de la izquierda tiene mas Tweets que son de NO Desastres y la zona más de la derecha son de Desastres.
# Tambien podemos identificar clusters que hablan de lo mismo por ejemplo de un choque de un avion o cosas como esas.

# %% [markdown]
# # Y si usamos un embedding mejor?
#  - Se nombro Bert que es un embedding mucho mejor, vamos a probarlo
# https://huggingface.co/docs/transformers/main/model_doc/bert

# %%
# @title Semilla y Carga de Datos

SEMILLA = 111014

# Cargar datos
train_file = '/content/drive/MyDrive/MATERIAS/Ciencia de Datos/nlp-getting-started/train.csv'
df_train = pd.read_csv(train_file)

print(f"Datos cargados: {df_train.shape}")
# Out:
# Datos cargados: (7613, 5)

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
from sklearn.manifold import TSNE
import plotly.express as px


model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(df_train['text'].tolist(), show_progress_bar=True)

tsne = TSNE(n_components=2, random_state=SEMILLA, perplexity=30, n_iter=1000, n_jobs=-1)
bert_2d = tsne.fit_transform(embeddings)

df_bert_viz = pd.DataFrame(bert_2d, columns=['x', 'y'])
df_bert_viz['target_label'] = df_train['target'].map({0: 'No Desastre', 1: 'Desastre'})
df_bert_viz['text'] = df_train['text']
df_bert_viz['keyword'] = df_train['keyword'].fillna('Sin Keyword')
df_bert_viz['location'] = df_train['location'].fillna('Sin Location')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Batches:   0%|          | 0/238 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
# Gráfico interactivo
fig = px.scatter(
    df_bert_viz,
    x='x',
    y='y',
    color='target_label',
    hover_data={
        'x': False,
        'y': False,
        'target_label': True,
        'keyword': True,
        'location': True,
        'text': True
    },
    title='Mapa Semántico de Tweets (BERT + t-SNE)',
    color_discrete_map={'No Desastre': '#808080', 'Desastre': '#C0392B'},
    opacity=0.6,
    width=1000,
    height=800
)

fig.update_traces(marker=dict(size=5))
fig.update_layout(
    legend_title_text='Clase Real',
    template='plotly_white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2d4635b0-948b-4bbf-bdc7-eb52915a4e6b" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d4635b0-948b-4bbf-bdc7-eb52915a4e6b")) {                    Plotly.newPlot(                        "2d4635b0-948b-4bbf-bdc7-eb52915a4e6b",                        [{"customdata":[["Desastre","Sin Keyword","Sin Location","Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all"],["Desastre","Sin Keyword","Sin Location","Forest fire near La Ronge Sask. Canada"],["Desastre","Sin Keyword","Sin Location","All residents asked to 'shelter in place' are being notified by officers. No other evacuation or shelter in place orders are expected"],["Desastre","Sin Keyword","Sin Location","13,000 people receive #wildfires evacuation orders in California "],["Desastre","Sin Keyword","Sin Location","Just got sent this photo from Ruby #Alaska as smoke from #wildfires pours into a school "],["Desastre","Sin Keyword","Sin Location","#RockyFire Update =\u003e California Hwy. 20 closed in both directions due to Lake County fire - #CAfire #wildfires"],["Desastre","Sin Keyword","Sin Location","#flood #disaster Heavy rain causes flash flooding of streets in Manitou, Colorado Springs areas"],["Desastre","Sin Keyword","Sin Location","I'm on top of the hill and I can see a fire in the woods..."],["Desastre","Sin Keyword","Sin Location","There's an emergency evacuation happening now in the building across the street"],["Desastre","Sin Keyword","Sin Location","I'm afraid that the tornado is coming to our area..."],["Desastre","Sin Keyword","Sin Location","Three people died from the heat wave so far"],["Desastre","Sin Keyword","Sin Location","Haha South Tampa is getting flooded hah- WAIT A SECOND I LIVE IN SOUTH TAMPA WHAT AM I GONNA DO WHAT AM I GONNA DO FVCK #flooding"],["Desastre","Sin Keyword","Sin Location","#raining #flooding #Florida #TampaBay #Tampa 18 or 19 days. I've lost count "],["Desastre","Sin Keyword","Sin Location","#Flood in Bago Myanmar #We arrived Bago"],["Desastre","Sin Keyword","Sin Location","Damage to school bus on 80 in multi car crash #BREAKING "],["Desastre","ablaze","Birmingham","@bbcmtd Wholesale Markets ablaze http:\u002f\u002ft.co\u002flHYXEOHY6C"],["Desastre","ablaze","AFRICA","#AFRICANBAZE: Breaking news:Nigeria flag set ablaze in Aba. http:\u002f\u002ft.co\u002f2nndBGwyEi"],["Desastre","ablaze","World Wide!!","INEC Office in Abia Set Ablaze - http:\u002f\u002ft.co\u002f3ImaomknnA"],["Desastre","ablaze","Sin Location","Barbados #Bridgetown JAMAICA ÛÒ Two cars set ablaze: SANTA CRUZ ÛÓ Head of the St Elizabeth Police Superintende...  http:\u002f\u002ft.co\u002fwDUEaj8Q4J"],["Desastre","ablaze","GREENSBORO,NORTH CAROLINA","How the West was burned: Thousands of wildfires ablaze in California alone http:\u002f\u002ft.co\u002fvl5TBR3wbr"],["Desastre","ablaze","Sheffield Township, Ohio","Deputies: Man shot before Brighton home set ablaze http:\u002f\u002ft.co\u002fgWNRhMSO8k"],["Desastre","ablaze","India","Man wife get six years jail for setting ablaze niece\nhttp:\u002f\u002ft.co\u002feV1ahOUCZA"],["Desastre","ablaze","Anaheim","Police: Arsonist Deliberately Set Black Church In North CarolinaåÊAblaze http:\u002f\u002ft.co\u002fpcXarbH9An"],["Desastre","ablaze","USA","#Kurds trampling on Turkmen flag later set it ablaze while others vandalized offices of Turkmen Front in #Diyala http:\u002f\u002ft.co\u002f4IzFdYC3cg"],["Desastre","ablaze","South Africa","TRUCK ABLAZE : R21. VOORTREKKER AVE. OUTSIDE OR TAMBO INTL. CARGO SECTION. http:\u002f\u002ft.co\u002f8kscqKfKkF"],["Desastre","ablaze","Edmonton, Alberta - Treaty 6","How the West was burned: Thousands of wildfires ablaze in #California alone http:\u002f\u002ft.co\u002fi ...

# %% [markdown]
# # En este Embedding, se puede ver más claramente la diferencia del target y se podria predecir con mayor precision.
# ## Tambien al igual que antes, podemos identificar clusters del Mismo Target que hablan del mismo tema, lo que nos dice que es un buen Embedding
